# %%
import geopandas as gpd
import psycopg2  # (if it is postgres/postgis)
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

con = psycopg2.connect(database="postgis-database", user="postgis", password="postgis", host="localhost", port=35432)

# sql = "SELECT ST_Buffer(geom, 0.54, 'quad_segs=8') as geom FROM polder3_l1b_bg1  WHERE ST_DWithin (  geography (ST_Point(lon,lat)),  geography (ST_Point(8.7979694, 53.0763431)), 60000)"
sql = "SELECT ST_Buffer( geom, 0.054, 'quad_segs=8') as geom FROM polder3_l1b_bg1  WHERE ST_DWithin (  geography (ST_Point(lon,lat)),  geography (ST_Point(8.7979694, 53.0763431)), 60000)"

data = gpd.read_postgis(sql=sql, con=con)
# data.plot()

# %%
fig, ax = plt.subplots(figsize=(18, 16))

data.to_crs(epsg=3857).plot(ax = ax,
figsize=(20,18),
color="black",
alpha=0.5,
);
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik);

# %%
from functools import reduce

reduce(lambda x,y: x+", "+y, ['1234','125.2','5553'])
# Out:
# '1234, 125.2, 5553'
